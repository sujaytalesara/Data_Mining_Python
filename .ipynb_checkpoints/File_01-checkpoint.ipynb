# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.offline as pyo
import seaborn as sns

# %%
df_train_Val = pd.read_csv('E:/Kaggle/Water_Table/Pump_it_Up_Data_Mining_the_Water_Table_-_Training_set_values.csv', index_col = 0)
df_train_Target = pd.read_csv('E:/Kaggle/Water_Table/Pump_it_Up_Data_Mining_the_Water_Table_-_Training_set_labels.csv',index_col = 0)

# %%
df_train = df_train_Val.merge(df_train_Target, how = 'left', left_index = True, right_index = True)

# %%
pd.options.display.max_columns = None
df_train.head()
# Out:
#        amount_tsh date_recorded        funder  gps_height     installer  \
# id
# 69572      6000.0    2011-03-14         Roman        1390         Roman
# 8776          0.0    2013-03-06       Grumeti        1399       GRUMETI
# 34310        25.0    2013-02-25  Lottery Club         686  World vision
# 67743         0.0    2013-01-28        Unicef         263        UNICEF
# 19728         0.0    2011-07-13   Action In A           0       Artisan
#
#        longitude   latitude              wpt_name  num_private  \
# id
# 69572  34.938093  -9.856322                  none            0
# 8776   34.698766  -2.147466              Zahanati            0
# 34310  37.460664  -3.821329           Kwa Mahundi            0
# 67743  38.486161 -11.155298  Zahanati Ya Nanyumbu            0
# 19728  31.130847  -1.825359               Shuleni            0
#
#                          basin  subvillage   region  region_code  \
# id
# 69572               Lake Nyasa    Mnyusi B   Iringa           11
# ...

# %%
df_train.columns.values
# Out:
# array(['amount_tsh', 'date_recorded', 'funder', 'gps_height', 'installer',
#        'longitude', 'latitude', 'wpt_name', 'num_private', 'basin',
#        'subvillage', 'region', 'region_code', 'district_code', 'lga',
#        'ward', 'population', 'public_meeting', 'recorded_by',
#        'scheme_management', 'scheme_name', 'permit', 'construction_year',
#        'extraction_type', 'extraction_type_group',
#        'extraction_type_class', 'management', 'management_group',
#        'payment', 'payment_type', 'water_quality', 'quality_group',
#        'quantity', 'quantity_group', 'source', 'source_type',
#        'source_class', 'waterpoint_type', 'waterpoint_type_group',
#        'status_group'], dtype=object)

# %%
df_train.isnull().sum()
# Out:
# amount_tsh                   0
# date_recorded                0
# funder                    3635
# gps_height                   0
# installer                 3655
# longitude                    0
# latitude                     0
# wpt_name                     0
# num_private                  0
# basin                        0
# subvillage                 371
# region                       0
# region_code                  0
# district_code                0
# lga                          0
# ward                         0
# population                   0
# public_meeting            3334
# recorded_by                  0
# scheme_management         3877
# scheme_name              28166
# permit                    3056
# construction_year            0
# extraction_type              0
# extraction_type_group        0
# extraction_type_class        0
# management                   0
# management_group             0
# payment                      0
# payment_type                 0
# ...

# %%
df_temp = df_train['population'][df_train['population'] > 0]
df_temp
# Out:
# id
# 69572    109
# 8776     280
# 34310    250
# 67743     58
# 9944       1
#         ...
# 44885    210
# 11164     89
# 60739    125
# 27263     56
# 26348    150
# Name: population, Length: 38019, dtype: int64

# %%
df_train
# Out:
#        amount_tsh date_recorded           funder  gps_height     installer  \
# id
# 69572      6000.0    2011-03-14            Roman        1390         Roman
# 8776          0.0    2013-03-06          Grumeti        1399       GRUMETI
# 34310        25.0    2013-02-25     Lottery Club         686  World vision
# 67743         0.0    2013-01-28           Unicef         263        UNICEF
# 19728         0.0    2011-07-13      Action In A           0       Artisan
# ...           ...           ...              ...         ...           ...
# 60739        10.0    2013-05-03  Germany Republi        1210           CES
# 27263      4700.0    2011-05-07      Cefa-njombe        1212          Cefa
# 37057         0.0    2011-04-11              NaN           0           NaN
# 31282         0.0    2011-03-08            Malec           0          Musa
# 26348         0.0    2011-03-23       World Bank         191         World
#
# ...

# %%
plt.figure(figsize = (13,6))
sns.countplot(df_train.status_group)
df_train.status_group.value_counts()
# Out:
# functional                 32259
# non functional             22824
# functional needs repair     4317
# Name: status_group, dtype: int64

# %%
temp_unique = df_train.nunique()
# temp_unique.sort_values()
temp_unique
# Out:
# amount_tsh                  98
# date_recorded              356
# funder                    1897
# gps_height                2428
# installer                 2145
# longitude                57516
# latitude                 57517
# wpt_name                 37400
# num_private                 65
# basin                        9
# subvillage               19287
# region                      21
# region_code                 27
# district_code               20
# lga                        125
# ward                      2092
# population                1049
# public_meeting               2
# recorded_by                  1
# scheme_management           12
# scheme_name               2696
# permit                       2
# construction_year           55
# extraction_type             18
# extraction_type_group       13
# extraction_type_class        7
# management                  12
# management_group             5
# payment                      7
# payment_type                 7
# ...

# %%
plt.figure(figsize = (20,6))
sns.countplot(data = df_train, x = 'basin', hue = 'status_group')

# %%
plt.figure(figsize = (20,6))
sns.countplot(data = df_train, x = 'permit', hue = 'status_group')

# %%
plt.figure(figsize = (20,6))
sns.countplot(data = df_train, x = 'extraction_type', hue = 'status_group')

# %%
plt.figure(figsize = (20,6))
sns.countplot(data = df_train, x = 'extraction_type_group', hue = 'status_group')

# %%
plt.figure(figsize = (20,6))
sns.countplot(data = df_train, x = 'extraction_type_class', hue = 'status_group')

# %%
plt.figure(figsize = (20,6))
sns.countplot(data = df_train, x = 'management', hue = 'status_group')

# %%
plt.figure(figsize = (20,6))
sns.countplot(data = df_train, x = 'management_group', hue = 'status_group')

# %%
plt.figure(figsize = (20,6))
sns.countplot(data = df_train, x = 'payment', hue = 'status_group')

# %%
plt.figure(figsize = (20,6))
sns.countplot(data = df_train, x = 'payment_type', hue = 'status_group')

# %%
plt.figure(figsize = (14,6))
sns.countplot(data = df_train, x = 'public_meeting', hue = 'status_group')

# %%
plt.figure(figsize = (20,6))
sns.countplot(data = df_train, x = 'quality_group', hue = 'status_group')

# %%
plt.figure(figsize = (20,6))
sns.countplot(data = df_train, x = 'quantity', hue = 'status_group')

# %%
plt.figure(figsize = (20,6))
sns.countplot(data = df_train, x = 'quantity_group', hue = 'status_group')

# %%
plt.figure(figsize = (20,6))
sns.countplot(data = df_train, x = 'scheme_management', hue = 'status_group')

# %%
plt.figure(figsize = (20,6))
sns.countplot(data = df_train, x = 'source', hue = 'status_group')

# %%
plt.figure(figsize = (20,6))
sns.countplot(data = df_train, x = 'source_type', hue = 'status_group')

# %%
plt.figure(figsize = (20,6))
sns.countplot(data = df_train, x = 'source_class', hue = 'status_group')

# %%
plt.figure(figsize = (20,6))
sns.countplot(data = df_train, x = 'water_quality', hue = 'status_group')

# %%
plt.figure(figsize = (20,6))
sns.countplot(data = df_train, x = 'waterpoint_type', hue = 'status_group')

# %%
plt.figure(figsize = (20,6))
sns.countplot(data = df_train, x = 'waterpoint_type_group', hue = 'status_group')
